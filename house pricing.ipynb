# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("archive/housing.csv")

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
data.dropna(inplace=True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
from sklearn.model_selection import train_test_split

x=data.drop(['median_house_value'], axis=1)
y=data['median_house_value']

# %%
x
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income ocean_proximity
# 0           322.0       126.0         8.3252        NEAR BAY
# 1          2401.0      1138.0         8.3014        NEAR BAY
# 2           496.0       177.0         7.2574        NEAR BAY
# 3           558.0       219.0         5.6431        NEAR BAY
# 4           565.0       259.0         3.8462        NEAR BAY
# ...           ...         ...            ...             ...
# 20635       845.0       330.0         1.5603          INLAND
# 20636       356.0       114.0         2.5568          INLAND
# 20637      1007.0       433.0         1.7000          INLAND
# 20638       741.0       349.0         1.8672          INLAND
# 20639      1387.0       530.0         2.3886          INLAND
#
# [20433 rows x 9 columns]

# %%
y
# Out:
# 0        452600.0
# 1        358500.0
# 2        352100.0
# 3        341300.0
# 4        342200.0
#            ...
# 20635     78100.0
# 20636     77100.0
# 20637     92300.0
# 20638     84700.0
# 20639     89400.0
# Name: median_house_value, Length: 20433, dtype: float64

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
train_data = x_train.join(y_train)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 5854     -118.33     34.17                48.0       2584.0           483.0
# 18862    -122.21     38.11                31.0       2766.0           604.0
# 14172    -117.06     32.76                24.0       1629.0           587.0
# 3509     -118.46     34.25                33.0       2202.0           433.0
# 18674    -121.90     36.97                21.0       3707.0           751.0
# ...          ...       ...                 ...          ...             ...
# 2721     -115.53     32.73                14.0       1527.0           325.0
# 8776     -118.32     33.80                29.0       3254.0           717.0
# 4378     -118.27     34.09                52.0       3225.0           763.0
# 8259     -118.18     33.77                30.0       1418.0           439.0
# 19686    -121.62     39.13                41.0       1317.0           309.0
#
#        population  households  median_income ocean_proximity  \
# 5854       1118.0       459.0         4.2396       <1H OCEAN
# 18862      1441.0       552.0         3.1768        NEAR BAY
# 14172      1012.0       488.0         1.7452      NEAR OCEAN
# 3509       1135.0       407.0         4.2143       <1H OCEAN
# 18674      1420.0       608.0         4.4485      NEAR OCEAN
# ...           ...         ...            ...             ...
# 2721       1453.0       332.0         1.7350          INLAND
# 8776       1593.0       680.0         4.0536       <1H OCEAN
# 4378       1559.0       710.0         3.9674       <1H OCEAN
# 8259        720.0       417.0         2.6371      NEAR OCEAN
# 19686       856.0       337.0         1.6719          INLAND
#
#        median_house_value
# 5854             245100.0
# 18862            131000.0
# 14172            156800.0
# 3509             224200.0
# 18674            295200.0
# ...                   ...
# 2721              61200.0
# 8776             285800.0
# 4378             268800.0
# 8259             159400.0
# 19686             64100.0
#
# [16346 rows x 10 columns]

# %%
train_data.hist(figsize = (15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
# Remove non-numeric columns
numeric_data = train_data.select_dtypes(include=['float64'])

# Calculate the correlation matrix
numeric_data.corr()
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924058           -0.116090     0.050479
# latitude            -0.924058  1.000000            0.018665    -0.041878
# housing_median_age  -0.116090  0.018665            1.000000    -0.359761
# total_rooms          0.050479 -0.041878           -0.359761     1.000000
# total_bedrooms       0.073978 -0.071148           -0.320645     0.932063
# population           0.102059 -0.111548           -0.296120     0.857350
# households           0.061025 -0.076382           -0.303780     0.921026
# median_income       -0.014764 -0.080943           -0.118144     0.194621
# median_house_value  -0.045468 -0.145132            0.105597     0.133015
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.073978    0.102059    0.061025      -0.014764
# latitude                 -0.071148   -0.111548   -0.076382      -0.080943
# housing_median_age       -0.320645   -0.296120   -0.303780      -0.118144
# total_rooms               0.932063    0.857350    0.921026       0.194621
# total_bedrooms            1.000000    0.875931    0.979909      -0.007504
# population                0.875931    1.000000    0.905162       0.006841
# households                0.979909    0.905162    1.000000       0.013907
# median_income            -0.007504    0.006841    0.013907       1.000000
# median_house_value        0.050796   -0.022182    0.066353       0.688060
#
#                     median_house_value
# longitude                    -0.045468
# latitude                     -0.145132
# housing_median_age            0.105597
# total_rooms                   0.133015
# total_bedrooms                0.050796
# population                   -0.022182
# households                    0.066353
# median_income                 0.688060
# median_house_value            1.000000

# %%
plt.figure(figsize=(15,8))
sns.heatmap(numeric_data.corr(),annot=True,cmap="YlGnBu")
# Out:
# <Axes: >

# %%
# Apply log transformation with error handling to avoid log(0)
train_data['total_rooms'] = np.log(train_data['total_rooms'] + 1)
train_data['total_bedrooms'] = np.log(train_data['total_bedrooms'] + 1)
train_data['population'] = np.log(train_data['population'] + 1)
train_data['households'] = np.log(train_data['households'] + 1)

# Plot the histograms
train_data.hist(figsize=(15, 8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_data.ocean_proximity.value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     7220
# INLAND        5158
# NEAR OCEAN    2104
# NEAR BAY      1860
# ISLAND           4
# Name: count, dtype: int64

# %%
pd.get_dummies(train_data.ocean_proximity)
# Out:
#        <1H OCEAN  INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 5854        True   False   False     False       False
# 18862      False   False   False      True       False
# 14172      False   False   False     False        True
# 3509        True   False   False     False       False
# 18674      False   False   False     False        True
# ...          ...     ...     ...       ...         ...
# 2721       False    True   False     False       False
# 8776        True   False   False     False       False
# 4378        True   False   False     False       False
# 8259       False   False   False     False        True
# 19686      False    True   False     False       False
#
# [16346 rows x 5 columns]

# %%
train_data = train_data.join(pd.get_dummies(train_data['ocean_proximity'])).drop(['ocean_proximity'],axis=1)
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 5854     -118.33     34.17                48.0     7.857481        6.182085
# 18862    -122.21     38.11                31.0     7.925519        6.405228
# 14172    -117.06     32.76                24.0     7.396335        6.376727
# 3509     -118.46     34.25                33.0     7.697575        6.073045
# 18674    -121.90     36.97                21.0     8.218248        6.622736
# ...          ...       ...                 ...          ...             ...
# 2721     -115.53     32.73                14.0     7.331715        5.786897
# 8776     -118.32     33.80                29.0     8.087948        6.576470
# 4378     -118.27     34.09                52.0     8.078998        6.638568
# 8259     -118.18     33.77                30.0     7.257708        6.086775
# 19686    -121.62     39.13                41.0     7.183871        5.736572
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 5854     7.020191    6.131226         4.2396            245100.0       True
# 18862    7.273786    6.315358         3.1768            131000.0      False
# 14172    6.920672    6.192362         1.7452            156800.0      False
# 3509     7.035269    6.011267         4.2143            224200.0       True
# 18674    7.259116    6.411818         4.4485            295200.0      False
# ...           ...         ...            ...                 ...        ...
# 2721     7.282074    5.808142         1.7350             61200.0      False
# 8776     7.374002    6.523562         4.0536            285800.0       True
# 4378     7.352441    6.566672         3.9674            268800.0       True
# 8259     6.580639    6.035481         2.6371            159400.0      False
# 19686    6.753438    5.823046         1.6719             64100.0      False
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 5854    False   False     False       False
# 18862   False   False      True       False
# 14172   False   False     False        True
# 3509    False   False     False       False
# 18674   False   False     False        True
# ...       ...     ...       ...         ...
# 2721     True   False     False       False
# 8776    False   False     False       False
# 4378    False   False     False       False
# 8259    False   False     False        True
# 19686    True   False     False       False
#
# [16346 rows x 14 columns]

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(),annot=True,cmap="YlGnBu")
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x="latitude",y="longitude",data=train_data,hue="median_house_value",palette="coolwarm")
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
train_data['bedrom_ratio']=train_data['total_bedrooms']/train_data['total_rooms']
train_data['household_rooms']=train_data['total_rooms']/train_data['households']

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(),annot=True,cmap="YlGnBu")
# Out:
# <Axes: >

# %%
from sklearn.linear_model import LinearRegression
x_train,y_train=train_data.drop(['median_house_value'],axis=1),train_data['median_house_value']
reg=LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
test_data = x_test.join(y_test)

test_data['total_rooms'] = np.log(test_data['total_rooms'] + 1)
test_data['total_bedrooms'] = np.log(test_data['total_bedrooms'] + 1)
test_data['population'] = np.log(test_data['population'] + 1)
test_data['households'] = np.log(test_data['households'] + 1)

test_data = test_data.join(pd.get_dummies(test_data['ocean_proximity'])).drop(['ocean_proximity'],axis=1)

test_data['bedrom_ratio']=test_data['total_bedrooms']/test_data['total_rooms']
test_data['household_rooms']=test_data['total_rooms']/test_data['households']

# %%
test_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16258    -121.26     37.96                43.0     6.846943        5.342334
# 7957     -118.17     33.88                42.0     7.406103        5.918894
# 18026    -121.92     37.25                34.0     7.710653        5.888878
# 18289    -122.11     37.38                22.0     8.199464        6.579251
# 18328    -122.14     37.45                52.0     8.253748        6.287859
# ...          ...       ...                 ...          ...             ...
# 6921     -118.03     34.01                10.0     8.784468        6.944087
# 16432    -121.23     38.12                22.0     5.976351        4.077537
# 7159     -118.16     34.04                38.0     6.981935        5.659482
# 19875    -119.29     36.33                19.0     6.675823        5.451038
# 6553     -118.07     34.17                36.0     7.789869        5.978886
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 16258    6.538140    5.204007         2.3056             62300.0      False
# 7957     7.057898    5.863631         3.0893            162700.0       True
# 18026    6.943122    5.902633         4.7917            243200.0       True
# 18289    7.192934    6.478510         5.0804            500001.0      False
# 18328    7.238497    6.293419         7.8647            500001.0      False
# ...           ...         ...            ...                 ...        ...
# 6921     7.998335    6.926577         6.2319            403700.0       True
# 16432    4.905275    4.060443         3.9500            178100.0      False
# 7159     7.336937    5.780744         2.7026            145000.0       True
# 19875    6.464588    5.407172         0.7445            112500.0      False
# 6553     7.103322    6.025866         5.5418            326100.0      False
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN  bedrom_ratio  household_rooms
# 16258    True   False     False       False      0.780251         1.315706
# 7957    False   False     False       False      0.799191         1.263058
# 18026   False   False     False       False      0.763733         1.306307
# 18289   False   False      True       False      0.802400         1.265641
# 18328   False   False      True       False      0.761819         1.311489
# ...       ...     ...       ...         ...           ...              ...
# 6921    False   False     False       False      0.790496         1.268226
# 16432    True   False     False       False      0.682279         1.471847
# 7159    False   False     False       False      0.810589         1.207792
# 19875    True   False     False       False      0.816534         1.234624
# 6553     True   False     False       False      0.767521         1.292738
#
# [4087 rows x 16 columns]

# %%
x_test,y_test=test_data.drop(['median_house_value'],axis=1),test_data['median_house_value']

# %%
x_test
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16258    -121.26     37.96                43.0     6.846943        5.342334
# 7957     -118.17     33.88                42.0     7.406103        5.918894
# 18026    -121.92     37.25                34.0     7.710653        5.888878
# 18289    -122.11     37.38                22.0     8.199464        6.579251
# 18328    -122.14     37.45                52.0     8.253748        6.287859
# ...          ...       ...                 ...          ...             ...
# 6921     -118.03     34.01                10.0     8.784468        6.944087
# 16432    -121.23     38.12                22.0     5.976351        4.077537
# 7159     -118.16     34.04                38.0     6.981935        5.659482
# 19875    -119.29     36.33                19.0     6.675823        5.451038
# 6553     -118.07     34.17                36.0     7.789869        5.978886
#
#        population  households  median_income  <1H OCEAN  INLAND  ISLAND  \
# 16258    6.538140    5.204007         2.3056      False    True   False
# 7957     7.057898    5.863631         3.0893       True   False   False
# 18026    6.943122    5.902633         4.7917       True   False   False
# 18289    7.192934    6.478510         5.0804      False   False   False
# 18328    7.238497    6.293419         7.8647      False   False   False
# ...           ...         ...            ...        ...     ...     ...
# 6921     7.998335    6.926577         6.2319       True   False   False
# 16432    4.905275    4.060443         3.9500      False    True   False
# 7159     7.336937    5.780744         2.7026       True   False   False
# 19875    6.464588    5.407172         0.7445      False    True   False
# 6553     7.103322    6.025866         5.5418      False    True   False
#
#        NEAR BAY  NEAR OCEAN  bedrom_ratio  household_rooms
# 16258     False       False      0.780251         1.315706
# 7957      False       False      0.799191         1.263058
# 18026     False       False      0.763733         1.306307
# 18289      True       False      0.802400         1.265641
# 18328      True       False      0.761819         1.311489
# ...         ...         ...           ...              ...
# 6921      False       False      0.790496         1.268226
# 16432     False       False      0.682279         1.471847
# 7159      False       False      0.810589         1.207792
# 19875     False       False      0.816534         1.234624
# 6553      False       False      0.767521         1.292738
#
# [4087 rows x 15 columns]

# %%
x_train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 5854     -118.33     34.17                48.0     7.857481        6.182085
# 18862    -122.21     38.11                31.0     7.925519        6.405228
# 14172    -117.06     32.76                24.0     7.396335        6.376727
# 3509     -118.46     34.25                33.0     7.697575        6.073045
# 18674    -121.90     36.97                21.0     8.218248        6.622736
# ...          ...       ...                 ...          ...             ...
# 2721     -115.53     32.73                14.0     7.331715        5.786897
# 8776     -118.32     33.80                29.0     8.087948        6.576470
# 4378     -118.27     34.09                52.0     8.078998        6.638568
# 8259     -118.18     33.77                30.0     7.257708        6.086775
# 19686    -121.62     39.13                41.0     7.183871        5.736572
#
#        population  households  median_income  <1H OCEAN  INLAND  ISLAND  \
# 5854     7.020191    6.131226         4.2396       True   False   False
# 18862    7.273786    6.315358         3.1768      False   False   False
# 14172    6.920672    6.192362         1.7452      False   False   False
# 3509     7.035269    6.011267         4.2143       True   False   False
# 18674    7.259116    6.411818         4.4485      False   False   False
# ...           ...         ...            ...        ...     ...     ...
# 2721     7.282074    5.808142         1.7350      False    True   False
# 8776     7.374002    6.523562         4.0536       True   False   False
# 4378     7.352441    6.566672         3.9674       True   False   False
# 8259     6.580639    6.035481         2.6371      False   False   False
# 19686    6.753438    5.823046         1.6719      False    True   False
#
#        NEAR BAY  NEAR OCEAN  bedrom_ratio  household_rooms
# 5854      False       False      0.786777         1.281551
# 18862      True       False      0.808178         1.254960
# 14172     False        True      0.862147         1.194429
# 3509      False       False      0.788956         1.280525
# 18674     False        True      0.805857         1.281734
# ...         ...         ...           ...              ...
# 2721      False       False      0.789297         1.262317
# 8776      False       False      0.813120         1.239805
# 4378      False       False      0.821707         1.230303
# 8259      False        True      0.838664         1.202507
# 19686     False       False      0.798535         1.233696
#
# [16346 rows x 15 columns]

# %%
reg.score(x_test,y_test)
# Out:
# 0.6683345667876339

# %% [markdown]
# ## Use Scaler

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_train_s=scaler.fit_transform(x_train)
reg=LinearRegression()
reg.fit(x_train_s,y_train)
# Out:
# LinearRegression()

# %%
x_test_s=scaler.transform(x_test)

# %%
reg.score(x_test_s,y_test)
# Out:
# 0.6683345667876339

# %% [markdown]
# ## Use RandomForest Regressor

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.5.0

# %%
from sklearn.ensemble import RandomForestRegressor
forest=RandomForestRegressor()
forest.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
forest.score(x_test,y_test)
# Out:
# 0.8159519067903447

# %%
forest.fit(x_train_s,y_train)
forest.score(x_test_s,y_test)
# Out:
# 0.8180001236097615

# %% [markdown]
# ## Use Grid Search CrossValidation

# %%
from sklearn.model_selection import GridSearchCV
forest = RandomForestRegressor()
param_grid={
    "n_estimators":[3,10,30],
    "max_features":[2,4,6,8]
}
grid_search = GridSearchCV(forest,param_grid,cv=5,
                           scoring="neg_mean_squared_error",
                           return_train_score=True)
grid_search.fit(x_train_s,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_features': [2, 4, 6, 8],
#                          'n_estimators': [3, 10, 30]},
#              return_train_score=True, scoring='neg_mean_squared_error')

# %%
grid_search.best_estimator_
# Out:
# RandomForestRegressor(max_features=8, n_estimators=30)

# %%
best_forest=grid_search.best_estimator_
best_forest.score(x_test_s,y_test)
# Out:
# 0.8127469704481253

# %% [markdown]
# much low accoracy(81.2<81.8)

# %%
from sklearn.model_selection import GridSearchCV
forest = RandomForestRegressor()
param_grid={
    "n_estimators":[30,50,100],
    "max_features":[8,12,20],
    "min_samples_split":[2,4,6,8]
}
grid_search = GridSearchCV(forest,param_grid,cv=5,
                           scoring="neg_mean_squared_error",
                           return_train_score=True)
grid_search.fit(x_train_s,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_features': [8, 12, 20],
#                          'min_samples_split': [2, 4, 6, 8],
#                          'n_estimators': [30, 50, 100]},
#              return_train_score=True, scoring='neg_mean_squared_error')

# %%
best_forest=grid_search.best_estimator_
best_forest.score(x_test_s,y_test)
# Out:
# 0.8182738866474996
